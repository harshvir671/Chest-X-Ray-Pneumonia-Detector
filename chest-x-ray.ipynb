# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import kagglehub
path = kagglehub.dataset_download("paultimothymooney/chest-xray-pneumonia")
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia

# %%
# Exploring dataset
base_dir = '/kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/'
train_pneumonia_dir = base_dir+'train/PNEUMONIA/'
train_normal_dir=base_dir+'train/NORMAL/'

test_pneumonia_dir = base_dir+'test/PNEUMONIA/'
test_normal_dir = base_dir+'test/NORMAL/'

val_normal_dir= base_dir+'val/NORMAL/'
val_pnrumonia_dir= base_dir+'val/PNEUMONIA/'

train_pn = [train_pneumonia_dir+"{}".format(i) for i in os.listdir(train_pneumonia_dir) ]
train_normal = [train_normal_dir+"{}".format(i) for i in os.listdir(train_normal_dir) ]

test_normal = [test_normal_dir+"{}".format(i) for i in os.listdir(test_normal_dir)]
test_pn = [test_pneumonia_dir+"{}".format(i) for i in os.listdir(test_pneumonia_dir)]

val_pn= [val_pnrumonia_dir+"{}".format(i) for i in os.listdir(val_pnrumonia_dir) ]
val_normal= [val_normal_dir+"{}".format(i) for i in os.listdir(val_normal_dir) ]

print ("Total images:",len(train_pn+train_normal+test_normal+test_pn+val_pn+val_normal))
print ("Total pneumonia images:",len(train_pn+test_pn+val_pn))
print ("Total Normal images:",len(train_normal+test_normal+val_normal))
# Out:
# Total images: 5856
# Total pneumonia images: 4273
# Total Normal images: 1583

# %%
#Dataset Preprocessing & Visualization¶
# Dataset Splitting (train 80% , test 15% and validation 5% )

# Gathering all pneumina and normal chest X-ray in two python list
pn = train_pn + test_pn + val_pn
normal = train_normal + test_normal + val_normal

# Spliting dataset in train set,test set and validation set.

train_imgs = pn[:3418]+ normal[:1224]  # 80% of 4273 Pneumonia and normal chest X-ray are 3418 and 1224 respectively.
test_imgs = pn[3418:4059]+ normal[1224:1502]
val_imgs = pn[4059:] + normal[1502:]

print("Total Train Images %s containing %s pneumonia and %s normal images"
      % (len(train_imgs),len(pn[:3418]),len(normal[:1224])))
print("Total Test Images %s containing %s pneumonia and %s normal images"
      % (len(test_imgs),len(pn[3418:4059]),len(normal[1224:1502])))
print("Total validation Images %s containing %s pneumonia and %s normal images"
      % (len(val_imgs),len(pn[4059:]),len(normal[1502:])))

import random
random.seed(10) #ensure reproducability

random.shuffle(train_imgs)
random.shuffle(test_imgs)
random.shuffle(val_imgs)
# Out:
# Total Train Images 4642 containing 3418 pneumonia and 1224 normal images
# Total Test Images 919 containing 641 pneumonia and 278 normal images
# Total validation Images 295 containing 214 pneumonia and 81 normal images

# %%
#Loading each image and their label into array

import cv2
img_size = 224

def preprocess_image(image_list):
    X = [] # images
    y = [] #labels (0 for Normal or 1 for Pneumonia)
    count=0

    for image in image_list:

        try:

            img = cv2.imread(image,cv2.IMREAD_GRAYSCALE)

            img=cv2.resize(img,(img_size,img_size),interpolation=cv2.INTER_CUBIC)
            #convert image to 2D to 3D
            img = np.dstack([img, img, img])

            #convrt greyscale image to RGB
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

            # Normalalize Image
            img = img.astype(np.float32)/255.

            count=count+1

            X.append(img)


        except:
            continue
        #get the labels
        if 'NORMAL' in image:
            y.append(0)

        elif 'IM' in image:
            y.append(0)

        elif 'virus' or 'bacteria' in image:
            y.append(1)


    return X, y

# %%
X, y = preprocess_image(train_imgs)

# %%
# Check all the images getting labels or not
arr=y
uniqueValues, occurCount = np.unique(arr, return_counts=True)

print("Unique Values : " , uniqueValues)
print("Occurrence Count : ", occurCount)
# Out:
# Unique Values :  [0 1]
# Occurrence Count :  [1224 3418]

# %%
# Display some images from train set
# Feel free to show more image by changing the values

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(20, 5))
k=1
for i in range(4):
    a = fig.add_subplot(1, 4, k)
    if (y[i]==0):
        a.set_title('Normal')
    else:
        a.set_title('Pneumonia')

    plt.imshow(X[i])
    k=k+1

# %%
# get the labels for test set
P, t = preprocess_image(test_imgs)

# %%
arr=t
uniqueValues, occurCount = np.unique(arr, return_counts=True)

print("Unique Values : " , uniqueValues)
print("Occurrence Count : ", occurCount)
# Out:
# Unique Values :  [0 1]
# Occurrence Count :  [278 641]

# %%
# now displaying some images from test set

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(20, 5))
k=1
for i in range(4):
    a = fig.add_subplot(1, 4, k)
    if (t[i]==0):
        a.set_title('Normal')
    else:
        a.set_title('Pneumonia')

    plt.imshow(P[i])
    k=k+1

# %%
# get the labels for validation set
K, m = preprocess_image(val_imgs)

# %%
arr=m

# Get a tuple of unique values & their frequency in numpy array
uniqueValues, occurCount = np.unique(arr, return_counts=True)

print("Unique Values : " , uniqueValues)
print("Occurrence Count : ", occurCount)
# Out:
# Unique Values :  [0 1]
# Occurrence Count :  [ 81 214]

# %%
# now displaying some images from validation set
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(20, 5))
k=1
for i in range(4):
    a = fig.add_subplot(1, 4, k)
    if (m[i]==0):
        a.set_title('Normal')
    else:
        a.set_title('Pneumonia')

    plt.imshow(K[i])
    k=k+1

# %%
#Let's count and show the quantity of image in each set by counplot from Seaborn
import seaborn as sns
fig, ax = plt.subplots(1, 3, figsize=(15, 7))

sns.countplot(x=y, ax=ax[0], palette=['skyblue', 'orange'])
ax[0].set_title('Train')
ax[0].set(ylim=(0, 3500))

sns.countplot(x=t, ax=ax[1], palette=['skyblue', 'orange'])
ax[1].set_title('Test')
ax[1].set(ylim=(0, 3500))

sns.countplot(x=m, ax=ax[2], palette=['skyblue', 'orange'])
ax[2].set_title('Val')
ax[2].set(ylim=(0, 3500))

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_24/2773690719.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=y, ax=ax[0], palette=['skyblue', 'orange'])
# /tmp/ipykernel_24/2773690719.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=t, ax=ax[1], palette=['skyblue', 'orange'])
# /tmp/ipykernel_24/2773690719.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=m, ax=ax[2], palette=['skyblue', 'orange'])

# %%
#Dealing with class imbalance
#One of the simplest ways to solve the class imbalance is to simply provide a weight for each class which places more emphasis on the minority classes so CNN model can learn equally from all classes. Here, we employ sklearn compute class weight function to set weight for each class.

from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y),   # y = array of training labels
    y=y
)
class_weights = dict(enumerate(class_weights))
print(class_weights)
# Out:
# {0: np.float64(1.8962418300653594), 1: np.float64(0.679052077238151)}

# %%
import gc

train_imgs = train_pn[:3875]+ train_normal[:1341]
del train_imgs
gc.collect()

X_train = np.array(X)
y_train = np.array(y)
X_test = np.array(P)
y_test = np.array(t)
X_val = np.array(K)
y_val = np.array(m)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
print(X_val.shape)
print(y_val.shape)
# Out:
# (4642, 224, 224, 3)
# (4642,)
# (919, 224, 224, 3)
# (919,)
# (295, 224, 224, 3)
# (295,)

# %%
#TRAINING
#Using a batch size of 32. Batch size should be a power of 2 (4, 8, 16, 32, 64, 128, 256,....).
#The batch size 32 means the model will train 32 training samples and then update its parameters once. Batch training is faster and memory efficient.

# clear memory
del X
del y
gc.collect()

#get the length of the train and validation data
ntrain = len(X_train)
nval = len(X_val)

batch_size = 32

# %%
import tensorflow as tf
print(tf.__version__)
#Image Augmentation¶
#Lets build an input pipline for model with the augmentation technique. We artificially increase the dataset with augmentation technique, since we are using a small dataset.
# It also helps prevent overfitting

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(  rotation_range=7,
                                     width_shift_range=0.05,
                                     height_shift_range=0.05,
                                     shear_range=0.2,
                                     zoom_range=0.45,
                                     horizontal_flip=True)

val_datagen = ImageDataGenerator(zoom_range=0.45)
# Out:
# 2026-03-26 14:52:31.806826: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774536752.018779      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774536752.079261      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774536752.550759      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774536752.550789      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774536752.550791      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774536752.550794      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2.19.0

# %%
#Create the image generators
train_generator = train_datagen.flow(X_train, y_train, batch_size=batch_size)
val_generator = val_datagen.flow(X_val, y_val, batch_size=batch_size)

# %%
# Set image Size
img_size =224

# %%
#Train full train set with MobileNet¶

from keras import layers
from keras import models
from keras import optimizers
from keras.applications import *
from keras.layers import Dense, GlobalAveragePooling2D
from keras.preprocessing.image import img_to_array, load_img
from keras.models import Model
from keras import backend as K

# Create the base pre-trained model
# Weights should be none becuase we don't need to train with any pre-trained weights here

base_model = MobileNet(weights=None, include_top=False,input_shape=(img_size, img_size, 3))

x = base_model.output

# Add a global spatial average pooling layer
x = GlobalAveragePooling2D()(x)

# Add a logistic layer
predictions = Dense(1, activation="sigmoid")(x)

model = Model(inputs=base_model.input, outputs=predictions)
# Compile model
model.compile(optimizer='adam', loss = 'binary_crossentropy',
                           metrics = ['binary_accuracy', 'mae'])
# Out:
# I0000 00:00:1774536776.577627      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1774536776.583382      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
#Keep your GPU on or training time will be so high. Check your kaggle notebook's settings

# We train for 64 epochs
history = model.fit(train_generator,
                              steps_per_epoch=ntrain // batch_size,
                              epochs=64,
                              validation_data=val_generator,
                              validation_steps=nval // batch_size,
                              class_weight =class_weights,
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/64
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774536791.189635      78 service.cc:152] XLA service 0x781ce40067c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1774536791.189677      78 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1774536791.189682      78 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1774536793.380783      78 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-03-26 14:53:21.747224: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-26 14:53:21.885558: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-26 14:53:22.023837: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1774536813.319593      78 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  74/145 ━━━━━━━━━━━━━━━━━━━━ 22s 310ms/step - binary_accuracy: 0.7157 - loss: 0.5620 - mae: 0.3200
# 2026-03-26 14:54:06.417284: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-26 14:54:06.555039: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 107s 484ms/step - binary_accuracy: 0.7627 - loss: 0.4899 - mae: 0.2783 - val_binary_accuracy: 0.7222 - val_loss: 0.9215 - val_mae: 0.2957
# Epoch 2/64
#   1/145 ━━━━━━━━━━━━━━━━━━━━ 16s 117ms/step - binary_accuracy: 0.9062 - loss: 0.3141 - mae: 0.1877
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.9062 - loss: 0.3141 - mae: 0.1877 - val_binary_accuracy: 0.7222 - val_loss: 0.9293 - val_mae: 0.2952
# Epoch 3/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 49s 335ms/step - binary_accuracy: 0.8596 - loss: 0.3084 - mae: 0.1770 - val_binary_accuracy: 0.7188 - val_loss: 1.1520 - val_mae: 0.2889
# Epoch 4/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - binary_accuracy: 0.9375 - loss: 0.1311 - mae: 0.1200 - val_binary_accuracy: 0.7222 - val_loss: 1.1375 - val_mae: 0.2855
# Epoch 5/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 48s 329ms/step - binary_accuracy: 0.8921 - loss: 0.2473 - mae: 0.1483 - val_binary_accuracy: 0.7257 - val_loss: 1.1758 - val_mae: 0.2807
# Epoch 6/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.9688 - loss: 0.2974 - mae: 0.1535 - val_binary_accuracy: 0.7257 - val_loss: 1.1713 - val_mae: 0.2808
# Epoch 7/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 49s 334ms/step - binary_accuracy: 0.9019 - loss: 0.2367 - mae: 0.1405 - val_binary_accuracy: 0.7326 - val_loss: 3.3489 - val_mae: 0.2674
# Epoch 8/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.9375 - loss: 0.2386 - mae: 0.1108 - val_binary_accuracy: 0.7326 - val_loss: 3.4692 - val_mae: 0.2674
# Epoch 9/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 49s 335ms/step - binary_accuracy: 0.9012 - loss: 0.2439 - mae: 0.1346 - val_binary_accuracy: 0.7188 - val_loss: 0.9168 - val_mae: 0.2673
# Epoch 10/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - binary_accuracy: 0.9688 - loss: 0.1896 - mae: 0.0945 - val_binary_accuracy: 0.7257 - val_loss: 0.7849 - val_mae: 0.2542
# Epoch 11/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 48s 332ms/step - binary_accuracy: 0.8930 - loss: 0.2481 - mae: 0.1451 - val_binary_accuracy: 0.7882 - val_loss: 0.6938 - val_mae: 0.2038
# Epoch 12/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 1.0000 - loss: 0.0618 - mae: 0.0761 - val_binary_accuracy: 0.8056 - val_loss: 0.6667 - val_mae: 0.2001
# Epoch 13/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 49s 335ms/step - binary_accuracy: 0.9099 - loss: 0.2105 - mae: 0.1232 - val_binary_accuracy: 0.7361 - val_loss: 0.7724 - val_mae: 0.2763
# Epoch 14/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.9062 - loss: 0.1896 - mae: 0.1148 - val_binary_accuracy: 0.7778 - val_loss: 0.6593 - val_mae: 0.2412
# Epoch 15/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 48s 331ms/step - binary_accuracy: 0.9267 - loss: 0.1783 - mae: 0.1053 - val_binary_accuracy: 0.6875 - val_loss: 1.0155 - val_mae: 0.3261
# Epoch 16/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - binary_accuracy: 0.9688 - loss: 0.1261 - mae: 0.0918 - val_binary_accuracy: 0.6979 - val_loss: 1.0058 - val_mae: 0.3242
# Epoch 17/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 47s 325ms/step - binary_accuracy: 0.9270 - loss: 0.1845 - mae: 0.1059 - val_binary_accuracy: 0.4062 - val_loss: 2.3161 - val_mae: 0.5842
# Epoch 18/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.9688 - loss: 0.0851 - mae: 0.0635 - val_binary_accuracy: 0.4097 - val_loss: 2.3308 - val_mae: 0.5711
# Epoch 19/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 48s 332ms/step - binary_accuracy: 0.9164 - loss: 0.1980 - mae: 0.1087 - val_binary_accuracy: 0.6389 - val_loss: 1.3551 - val_mae: 0.3869
# Epoch 20/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - binary_accuracy: 0.9375 - loss: 0.1757 - mae: 0.1174 - val_binary_accuracy: 0.5729 - val_loss: 1.5632 - val_mae: 0.4256
# Epoch 21/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 47s 325ms/step - binary_accuracy: 0.9250 - loss: 0.1958 - mae: 0.1108 - val_binary_accuracy: 0.6181 - val_loss: 1.3879 - val_mae: 0.3889
# Epoch 22/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.9375 - loss: 0.1332 - mae: 0.0811 - val_binary_accuracy: 0.6319 - val_loss: 1.2811 - val_mae: 0.3774
# Epoch 23/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 49s 334ms/step - binary_accuracy: 0.9328 - loss: 0.1723 - mae: 0.0994 - val_binary_accuracy: 0.7639 - val_loss: 0.8078 - val_mae: 0.2223
# Epoch 24/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.9688 - loss: 0.0988 - mae: 0.0655 - val_binary_accuracy: 0.7604 - val_loss: 0.8008 - val_mae: 0.2195
# Epoch 25/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 48s 330ms/step - binary_accuracy: 0.9270 - loss: 0.1771 - mae: 0.1008 - val_binary_accuracy: 0.6042 - val_loss: 1.3722 - val_mae: 0.4045
# Epoch 26/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - binary_accuracy: 0.9375 - loss: 0.2040 - mae: 0.1015 - val_binary_accuracy: 0.5868 - val_loss: 1.2433 - val_mae: 0.3980
# Epoch 27/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 48s 330ms/step - binary_accuracy: 0.9306 - loss: 0.1630 - mae: 0.0940 - val_binary_accuracy: 0.8090 - val_loss: 0.6348 - val_mae: 0.1970
# Epoch 28/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - binary_accuracy: 0.9688 - loss: 0.0561 - mae: 0.0431 - val_binary_accuracy: 0.7951 - val_loss: 0.6022 - val_mae: 0.2022
# Epoch 29/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 47s 323ms/step - binary_accuracy: 0.9294 - loss: 0.1715 - mae: 0.0976 - val_binary_accuracy: 0.6285 - val_loss: 1.3760 - val_mae: 0.3662
# Epoch 30/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.8750 - loss: 0.1445 - mae: 0.1228 - val_binary_accuracy: 0.6528 - val_loss: 1.4948 - val_mae: 0.3601
# Epoch 31/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 48s 330ms/step - binary_accuracy: 0.9334 - loss: 0.1583 - mae: 0.0877 - val_binary_accuracy: 0.9167 - val_loss: 0.2395 - val_mae: 0.1381
# Epoch 32/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.9688 - loss: 0.0439 - mae: 0.0430 - val_binary_accuracy: 0.8889 - val_loss: 0.3003 - val_mae: 0.1607
# Epoch 33/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 48s 328ms/step - binary_accuracy: 0.9338 - loss: 0.1737 - mae: 0.1015 - val_binary_accuracy: 0.8021 - val_loss: 0.7443 - val_mae: 0.1917
# Epoch 34/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - binary_accuracy: 0.9375 - loss: 0.1267 - mae: 0.0884 - val_binary_accuracy: 0.8403 - val_loss: 0.5629 - val_mae: 0.1581
# Epoch 35/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 48s 328ms/step - binary_accuracy: 0.9462 - loss: 0.1549 - mae: 0.0836 - val_binary_accuracy: 0.5035 - val_loss: 2.3604 - val_mae: 0.5035
# Epoch 36/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.9688 - loss: 0.0848 - mae: 0.0792 - val_binary_accuracy: 0.4479 - val_loss: 2.5860 - val_mae: 0.5368
# Epoch 37/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 48s 328ms/step - binary_accuracy: 0.9399 - loss: 0.1525 - mae: 0.0877 - val_binary_accuracy: 0.8264 - val_loss: 0.3694 - val_mae: 0.1982
# Epoch 38/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 1.0000 - loss: 0.0604 - mae: 0.0569 - val_binary_accuracy: 0.8299 - val_loss: 0.3901 - val_mae: 0.2219
# Epoch 39/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 47s 327ms/step - binary_accuracy: 0.9460 - loss: 0.1455 - mae: 0.0838 - val_binary_accuracy: 0.6458 - val_loss: 2.4458 - val_mae: 0.3804
# Epoch 40/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.9375 - loss: 0.1506 - mae: 0.1638 - val_binary_accuracy: 0.6007 - val_loss: 2.8608 - val_mae: 0.4123
# Epoch 41/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 48s 328ms/step - binary_accuracy: 0.9172 - loss: 0.2058 - mae: 0.1157 - val_binary_accuracy: 0.8750 - val_loss: 0.2908 - val_mae: 0.1609
# Epoch 42/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.8750 - loss: 0.1381 - mae: 0.1337 - val_binary_accuracy: 0.8611 - val_loss: 0.3146 - val_mae: 0.1721
# Epoch 43/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 48s 331ms/step - binary_accuracy: 0.9414 - loss: 0.1496 - mae: 0.0866 - val_binary_accuracy: 0.8681 - val_loss: 0.2946 - val_mae: 0.1596
# Epoch 44/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.9375 - loss: 0.0898 - mae: 0.0958 - val_binary_accuracy: 0.9236 - val_loss: 0.2253 - val_mae: 0.1266
# Epoch 45/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 49s 339ms/step - binary_accuracy: 0.9372 - loss: 0.1587 - mae: 0.0934 - val_binary_accuracy: 0.9062 - val_loss: 0.2976 - val_mae: 0.1318
# Epoch 46/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - binary_accuracy: 0.9688 - loss: 0.1736 - mae: 0.0737 - val_binary_accuracy: 0.9028 - val_loss: 0.2810 - val_mae: 0.1279
# Epoch 47/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 48s 333ms/step - binary_accuracy: 0.9453 - loss: 0.1308 - mae: 0.0776 - val_binary_accuracy: 0.8472 - val_loss: 0.4631 - val_mae: 0.1943
# Epoch 48/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - binary_accuracy: 0.9375 - loss: 0.0987 - mae: 0.0918 - val_binary_accuracy: 0.8299 - val_loss: 0.4899 - val_mae: 0.1969
# Epoch 49/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 48s 328ms/step - binary_accuracy: 0.9422 - loss: 0.1492 - mae: 0.0830 - val_binary_accuracy: 0.8958 - val_loss: 0.4082 - val_mae: 0.1126
# Epoch 50/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - binary_accuracy: 0.9062 - loss: 0.1396 - mae: 0.1005 - val_binary_accuracy: 0.9062 - val_loss: 0.3852 - val_mae: 0.1066
# Epoch 51/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 48s 332ms/step - binary_accuracy: 0.9495 - loss: 0.1307 - mae: 0.0728 - val_binary_accuracy: 0.5000 - val_loss: 1.9190 - val_mae: 0.4966
# Epoch 52/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.8125 - loss: 0.3976 - mae: 0.1965 - val_binary_accuracy: 0.5035 - val_loss: 1.7933 - val_mae: 0.4904
# Epoch 53/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 47s 327ms/step - binary_accuracy: 0.9400 - loss: 0.1622 - mae: 0.0930 - val_binary_accuracy: 0.8958 - val_loss: 0.3142 - val_mae: 0.1327
# Epoch 54/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.9375 - loss: 0.1390 - mae: 0.0821 - val_binary_accuracy: 0.8924 - val_loss: 0.3151 - val_mae: 0.1399
# Epoch 55/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 47s 326ms/step - binary_accuracy: 0.9474 - loss: 0.1347 - mae: 0.0773 - val_binary_accuracy: 0.6944 - val_loss: 1.3803 - val_mae: 0.3080
# Epoch 56/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.9062 - loss: 0.1797 - mae: 0.1137 - val_binary_accuracy: 0.7361 - val_loss: 1.1702 - val_mae: 0.2771
# Epoch 57/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 48s 329ms/step - binary_accuracy: 0.9105 - loss: 0.2259 - mae: 0.1296 - val_binary_accuracy: 0.2847 - val_loss: 2.7067 - val_mae: 0.6498
# Epoch 58/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.7500 - loss: 0.3775 - mae: 0.2481 - val_binary_accuracy: 0.3090 - val_loss: 2.3622 - val_mae: 0.6400
# Epoch 59/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 47s 327ms/step - binary_accuracy: 0.9319 - loss: 0.1871 - mae: 0.1113 - val_binary_accuracy: 0.7500 - val_loss: 0.6491 - val_mae: 0.2640
# Epoch 60/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.9375 - loss: 0.2356 - mae: 0.0907 - val_binary_accuracy: 0.7882 - val_loss: 0.5017 - val_mae: 0.2244
# Epoch 61/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 48s 330ms/step - binary_accuracy: 0.9437 - loss: 0.1550 - mae: 0.0858 - val_binary_accuracy: 0.8819 - val_loss: 0.3390 - val_mae: 0.1447
# Epoch 62/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.9375 - loss: 0.1360 - mae: 0.0759 - val_binary_accuracy: 0.8715 - val_loss: 0.3185 - val_mae: 0.1448
# Epoch 63/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 48s 333ms/step - binary_accuracy: 0.9380 - loss: 0.1425 - mae: 0.0836 - val_binary_accuracy: 0.8194 - val_loss: 0.3972 - val_mae: 0.2261
# Epoch 64/64
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.9688 - loss: 0.0955 - mae: 0.0700 - val_binary_accuracy: 0.8576 - val_loss: 0.3669 - val_mae: 0.2155

# %%
# Lets plot the train and val curve
# Get the details form the history object
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

#Train and validation accuracy
plt.plot(epochs, acc, 'b', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
plt.title('Training and Validation accurarcy')
plt.legend()

plt.figure()
#Train and validation loss
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()

plt.show()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# Predict on the test data
preds = model.predict(X_test)

# Round the predictions to 0 or 1
preds = np.round(preds)

# Calculate accuracy
acc = accuracy_score(y_test, preds) * 100

# Generate confusion matrix
cm = confusion_matrix(y_test, preds)
print('CONFUSION MATRIX ------------------')
print(cm)

# Unpack values from the confusion matrix
tn, fp, fn, tp = cm.ravel()

# Compute metrics
precision = tp / (tp + fp) * 100
recall = tp / (tp + fn) * 100   # Recall = Sensitivity
specificity = tn / (tn + fp) * 100
f1_score = 2 * (precision * recall) / (precision + recall)

# Print test metrics
print('\n============ TEST METRICS =============')
print('Accuracy: {:.2f}%'.format(acc))
print('Precision: {:.2f}%'.format(precision))
print('Recall (Sensitivity): {:.2f}%'.format(recall))
print('Specificity: {:.2f}%'.format(specificity))
print('F1-score: {:.2f}'.format(f1_score))

# Print final training accuracy
print('\n============ TRAIN METRIC =============')
print('Train Accuracy: {:.2f}%'.format(history.history['binary_accuracy'][-1] * 100))
# Out:
# 27/29 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2026-03-26 15:21:18.468144: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-26 15:21:18.606415: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 12s 344ms/step
# CONFUSION MATRIX ------------------
# [[277   1]
#  [291 350]]
#
# ============ TEST METRICS =============
# Accuracy: 68.23%
# Precision: 99.72%
# Recall (Sensitivity): 54.60%
# Specificity: 99.64%
# F1-score: 70.56
#
# ============ TRAIN METRIC =============
# Train Accuracy: 96.88%

# %%
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d",)
# Out:
# <Axes: >

# %%
#The ROC (receiver operating characteristic) curve indicates the diagnostic accuracy and porformance of a model.
# We show the ROC curve and also calculate AUC score.


from sklearn.metrics import roc_curve,roc_auc_score
from sklearn.metrics import auc

fpr , tpr , thresholds = roc_curve ( y_test , preds)
auc_keras = auc(fpr, tpr)
print("AUC Score:",auc_keras)
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % auc_keras)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
# Out:
# AUC Score: 0.7712123592857384
